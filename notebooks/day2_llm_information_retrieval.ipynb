# %%
# !pip install einops gradio sentence-transformers transformers accelerate bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 44.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 MB 11.2 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.8/288.8 kB 25.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 7.4 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Sat Jul 15 17:30:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
embedding_model.max_seq_length = 512
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ...
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
sample_document = """
Northern War II
===============

***"Do you really wish to know?"*** --- Spoilers from the books and/or adaptations to follow!

The **second Northern War** was an attempt by both [Nilfgaard](https://witcher.fandom.com/wiki/Nilfgaardian_Empire "Nilfgaardian Empire") and the [Northern Kingdoms](https://witcher.fandom.com/wiki/Northern_Kingdoms "Northern Kingdoms") to attack each other, starting in [1267](https://witcher.fandom.com/wiki/Timeline#1267 "Timeline") and ending in [1268](https://witcher.fandom.com/wiki/Timeline#1268 "Timeline"). In the case of the North, the rulers believed Nilfgaard would keep attacking them and thus they should be the first to strike but make it look like Nilfgaard was the aggressor in order to gain public support. While Nilfgaard, learning of this, quickly prepared its own arms, devised an elaborate plan and struck first, rapidly subduing many surprised northern kingdoms in a blitzkrieg.

In the end, Nilfgaard once more suffered a defeat due to the incompetence of the commanding officers and the loss at the massive and decisive [Battle of Brenna](https://witcher.fandom.com/wiki/Battle_of_Brenna "Battle of Brenna"). Despite this, [Emperor](https://witcher.fandom.com/wiki/Emperor "Emperor") [Emhyr var Emreis](https://witcher.fandom.com/wiki/Emhyr_var_Emreis "Emhyr var Emreis") ended up marrying [False Ciri](https://witcher.fandom.com/wiki/False_Ciri "False Ciri")(who everyone but a few rulers and mages believed was the real [Ciri](https://witcher.fandom.com/wiki/Ciri "Ciri")), thus solidifying [Cintra](https://witcher.fandom.com/wiki/Cintra "Cintra") as a part of the Empire.

Combatants
----------

**The Aggressors**

-   [Nilfgaardian Empire](https://witcher.fandom.com/wiki/Nilfgaardian_Empire "Nilfgaardian Empire")
-   [Elves](https://witcher.fandom.com/wiki/Elf "Elf") ([Scoia'tael](https://witcher.fandom.com/wiki/Scoia%27tael "Scoia'tael") insurgents and elves from [Dol Blathanna](https://witcher.fandom.com/wiki/Dol_Blathanna "Dol Blathanna"))
-   [Cintran](https://witcher.fandom.com/wiki/Cintra "Cintra") deserters from [Vissegerd](https://witcher.fandom.com/wiki/Vissegerd "Vissegerd")'s army
-   [Verden](https://witcher.fandom.com/wiki/Verden "Verden") (led by King [Ervyll](https://witcher.fandom.com/wiki/Ervyll "Ervyll"))

**Northerners**

-   [Redania](https://witcher.fandom.com/wiki/Redania "Redania")
-   [Temeria](https://witcher.fandom.com/wiki/Temeria "Temeria")
-   [Aedirn](https://witcher.fandom.com/wiki/Aedirn "Aedirn")
-   [Kaedwen](https://witcher.fandom.com/wiki/Kaedwen "Kaedwen")
-   [Rivia](https://witcher.fandom.com/wiki/Rivia "Rivia")
-   [Lyria](https://witcher.fandom.com/wiki/Lyria_and_Rivia "Lyria and Rivia")
-   [Verden](https://witcher.fandom.com/wiki/Verden "Verden") (insurgents led by Prince [Kistrin](https://witcher.fandom.com/wiki/Kistrin "Kistrin"))
-   [Cidaris](https://witcher.fandom.com/wiki/Cidaris "Cidaris")
-   [Skellige](https://witcher.fandom.com/wiki/Skellige "Skellige")
-   [Brugge](https://witcher.fandom.com/wiki/Brugge "Brugge")
### Phase II - Invasion of Brugge and Sodden

* * * * *

-   After a mere 16 days of peace, Emhyr suddenly breaks his truce with Temeria and invades the kingdom
-   [Brugge](https://witcher.fandom.com/wiki/Brugge "Brugge") is attacked from three sides - from the north via [Brokilon](https://witcher.fandom.com/wiki/Brokilon "Brokilon") by elven [squirrel](https://witcher.fandom.com/wiki/Squirrel "Squirrel") commandos; from the west and [Verden](https://witcher.fandom.com/wiki/Verden "Verden"), the Nilfgaardian Army; from the south and the other side of the Yaruga, the [Black Infantry](https://witcher.fandom.com/wiki/Black_Infantry "Black Infantry")
-   Night of August 4-5, the [4th Cavalry Army](https://witcher.fandom.com/wiki/4th_Cavalry_Army "4th Cavalry Army") is divided into three battle groups: "[Vreemde](https://witcher.fandom.com/wiki/Vreemde_Battle_Group "Vreemde Battle Group")", "[Sievers](https://witcher.fandom.com/wiki/Sievers_Battle_Group "Sievers Battle Group")", and "[Morteisen](https://witcher.fandom.com/wiki/Morteisen_Battle_Group "Morteisen Battle Group")", the groups set out for the [Drieschot](https://witcher.fandom.com/wiki/Drieschot "Drieschot") triangle near the [Vidort](https://witcher.fandom.com/wiki/Vidort "Vidort")-[Carcano](https://witcher.fandom.com/wiki/Carcano "Carcano")-[Armeria](https://witcher.fandom.com/wiki/Armeria "Armeria") boundary to cross the [Ina](https://witcher.fandom.com/wiki/Ina "Ina")
-   The siege and sacking of [Brugge](https://witcher.fandom.com/wiki/Brugge "Brugge")
-   Fierce Bruggian resistance
-   Siege of [Dillingen](https://witcher.fandom.com/wiki/Dillingen "Dillingen")
-   Fight over the [Chotla](https://witcher.fandom.com/wiki/Chotla "Chotla")
-   The [Battle of Armeria](https://witcher.fandom.com/wiki/Battle_of_Armeria "Battle of Armeria") (4th Cavalry Army and Cintran troops)
-   Fighting in [Angren](https://witcher.fandom.com/wiki/Angren "Angren")
-   The [Battle for the Bridge on the Yaruga](https://witcher.fandom.com/wiki/Battle_for_the_Bridge_on_the_Yaruga "Battle for the Bridge on the Yaruga")
-   Illegal Nilfgaardian expedition into [Angren](https://witcher.fandom.com/wiki/Angren "Angren") (from the east - through the [Klamat](https://witcher.fandom.com/wiki/Klamat "Klamat") pass)
-   Siege of the fortresses of [Razwan](https://witcher.fandom.com/wiki/Razwan "Razwan") and [Mayena](https://witcher.fandom.com/wiki/Mayena "Mayena"), cordoning off all of Sodden
-   Invasion of southern [Temeria](https://witcher.fandom.com/wiki/Temeria "Temeria")
-   The [Battle of Maribor](https://witcher.fandom.com/wiki/Battle_of_Maribor "Battle of Maribor")
-   The retreat of Nilfgaardian troops back to [Sodden](https://witcher.fandom.com/wiki/Sodden "Sodden")

#### The Spring Offensive Plan

Emperor [Emhyr var Emreis](https://witcher.fandom.com/wiki/Emhyr_var_Emreis "Emhyr var Emreis") gave up on his immediate military pursuits and decided to put off the offensive for a year. He did so for two reasons: first, the upcoming winter was predicted to be particularly harsh and cold, which complicated the key issue which was logistics and the supplying the army; and second, the attack on Temeria, while resulting in a solid victory at [Maribor](https://witcher.fandom.com/wiki/Maribor_(city) "Maribor (city)"), was simply too quick and easy - suggesting that the [Mayena Fortress](https://witcher.fandom.com/wiki/Mayena "Mayena") had been purposefully left under-defended. A great offensive was planned, but it would not begin until the following spring.

irn to defend himself there, the line of his defence settled by the city of Aldersberg. The forces of Nilfgaard and the Nordlings were balanced, so Henselt and Demavend were not hasty to attack. Everything changed when, suddenly, the main commander of the East Army, Ardal aep Dahy, died. After the Nordlings found about this, they attacked and the battle was later known as the "Second Battle of Aldersberg," where the conjoined forces of Aedirn and Kaedwen defeated the East Army, settling the war of the eastern front. This started the liberation of the kingdom of Aedirn, with the capital city of Vengerberg as one of the first cities liberated, the chaotic retreat of the East Army through Lyria where Queen Meve fought a guerrilla war, and the march of the Kaedwen's forces to the river Yaruga.

The end of the war
------------------

On the western front, Verden was liberated, however, there were still three fortresses occupied by Nilfgaard that were still resisting the Nordling's forces. King Foltest and his army liberated Lower Sodden from the Nilfgaard's occupation. Nilfgaard forces, greatly outnumbered, retreat through Yaruga river to empower the defence there. On the eastern front the Nilfgaard forces are retreating back to the empire, and the Kaedwen's army reaches Dol Angra, the place where the war started. Nilfgaard was losing on all fronts. Northern kings gave up the idea of liberating Cintra, they already controlled the right shore of Yaruga and all retreating Nilfgaardian forces were there, and together they were a great military power. Both north and south had enough of the destructive war. The negotiations started and there was a proposed truce, stop the military actions and don't cross the borders. It was settled that at the 2nd of April, all leaders of countries involved in war were to meet in Cintra to negotiate a peace and bring a new order to the world.

Peace of Cintra
---------------

[Peace of Cintra](https://witcher.fandom.com/wiki/Peace_of_Cintra "Peace of Cintra"), on 2 April year 1268, between the Northern Kingdoms and Nilfgaard ending the Second Nilfgaard War and a new order was brought to the world.
"""

# %%
import re 

def convert_heading_types(text):
    lines = text.split("\n")
    
    for i, line in enumerate(lines):
        if re.match(r"^[=]+$", line):
            lines[i-1] = f"# {lines[i-1]}"
        if re.match(r"^[-]+$", line):
            lines[i-1] = f"## {lines[i-1]}"
        
    filtered_lines = [l for l in lines if not re.match(r"^[=-]+$", l)]
    return "\n".join(filtered_lines)

def cleanup_urls(text):
    return re.sub(r"\[(.*?)\]\(.*?\)", r"\1", text)

def clean_markdown(text):
    return cleanup_urls(convert_heading_types(text))

clean_sample_document = clean_markdown(sample_document)
print(clean_sample_document)
# Out:
# # Northern War II
#
# ***"Do you really wish to know?"*** --- Spoilers from the books and/or adaptations to follow!
#
# The **second Northern War** was an attempt by both Nilfgaard and the Northern Kingdoms to attack each other, starting in 1267 and ending in 1268. In the case of the North, the rulers believed Nilfgaard would keep attacking them and thus they should be the first to strike but make it look like Nilfgaard was the aggressor in order to gain public support. While Nilfgaard, learning of this, quickly prepared its own arms, devised an elaborate plan and struck first, rapidly subduing many surprised northern kingdoms in a blitzkrieg.
#
# ...

# %%
def split_recursively(text, max_tokens=256, prev_headers=[], header_level=1):
    split_string = "(?:\n|^)" + "".join(["#"] * header_level) + " "
    sections = re.split(re.compile(split_string), text)
    
    fragments = []
    
    if len(sections) == 1:
        paragraphs = [par for par in text.split("\n\n") if not re.match(r"^\s*$", par)]
        running_block = "\n".join(prev_headers)
        for paragraph in paragraphs:
            running_block += "\n" + paragraph
            if embedding_model.tokenize(running_block)["input_ids"].shape[0] > max_tokens*0.5:
                fragments.append(running_block)
                running_block = "\n".join(prev_headers)
                
        if running_block != "\n".join(prev_headers):
            fragments.append((running_block, embedding_model.encode(running_block)))
    else:
        for section in sections:
            if not re.match(r"^\s*$", section):
                section_with_headers = "\n".join([*prev_headers, section])
                num_tokens = embedding_model.tokenize(section_with_headers)["input_ids"].shape[0]
                if num_tokens > max_tokens:
                    header = section.split("\n")[0]
                    fragments.extend(split_recursively("\n".join(section.split("\n")[1:]), header_level=header_level+1, prev_headers=[*prev_headers, header]))
                else:
                    fragments.append(section_with_headers)
                
    return fragments

# %%
sample_document_fragments = split_recursively(clean_sample_document)
sample_document_fragments = list(zip(sample_document_fragments, embedding_model.encode(sample_document_fragments)))
# Out:
# ...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
for fragment, embedding in sample_document_fragments:
    print("--------------------\n" + fragment + "\n")
# Out:
# --------------------
# Northern War II
#
# ***"Do you really wish to know?"*** --- Spoilers from the books and/or adaptations to follow!
# The **second Northern War** was an attempt by both Nilfgaard and the Northern Kingdoms to attack each other, starting in 1267 and ending in 1268. In the case of the North, the rulers believed Nilfgaard would keep attacking them and thus they should be the first to strike but make it look like Nilfgaard was the aggressor in order to gain public support. While Nilfgaard, learning of this, quickly prepared its own arms, devised an elaborate plan and struck first, rapidly subduing many surprised northern kingdoms in a blitzkrieg.
#
# --------------------
# Northern War II
#
# ...

# %%
embedding_model.tokenize("""Northern War II
The end of the war

On the western front, Verden was liberated, however, there were still three fortresses occupied by Nilfgaard that were still resisting the Nordling's forces. King Foltest and his army liberated Lower Sodden from the Nilfgaard's occupation. Nilfgaard forces, greatly outnumbered, retreat through Yaruga river to empower the defence there. On the eastern front the Nilfgaard forces are retreating back to the empire, and the Kaedwen's army reaches Dol Angra, the place where the war started. Nilfgaard was losing on all fronts. Northern kings gave up the idea of liberating Cintra, they already controlled the right shore of Yaruga and all retreating Nilfgaardian forces were there, and together they were a great military power. Both north and south had enough of the destructive war. The negotiations started and there was a proposed truce, stop the military actions and don't cross the borders. It was settled that at the 2nd of April, all leaders of countries involved in war were to meet in Cintra to negotiate a peace and bring a new order to the world.""")["input_ids"].shape[0]
# Out:
# 1093

# %%
# !python -m bitsandbytes
# Out:
# False
#
# ===================================BUG REPORT===================================
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:166: UserWarning: Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#
#   warn(msg)
# ...
# The following directories listed in your path were found to be non-existent: {PosixPath('/usr/local/cuda/lib'), PosixPath('/usr/local/lib/x86_64-linux-gnu'), PosixPath('/usr/local/nvidia/lib')}
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model = "tiiuae/falcon-7b-instruct"

tokenizer = AutoTokenizer.from_pretrained(model)
llm_pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    model_kwargs={"load_in_8bit": True}
)
# Out:
# ...
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
from transformers import StoppingCriteria, AutoModelForCausalLM, AutoTokenizer, StoppingCriteriaList

class KeywordsStoppingCriteria(StoppingCriteria):
    def __init__(self, keywords_ids: list):
        self.keywords = keywords_ids

    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
        if input_ids[0][-1] in self.keywords:
            return True
        return False

USER_NAME = "User"
stop_words = [f"\n{USER_NAME}:", f"{USER_NAME}"]
stop_ids = [tokenizer.encode(w)[0] for w in stop_words]
stop_criteria = KeywordsStoppingCriteria(stop_ids)

# %%
USER_NAME = "User"
BOT_NAME = "Falcon"
DEFAULT_INSTRUCTIONS = f"""The following is a conversation between a highly knowledgeable and intelligent AI assistant, called Falcon, and a human user, called User. In the following interactions, User and Falcon will converse in natural language, and Falcon will answer User's questions. Falcon was built to be respectful, polite and inclusive. Falcon will never decline to answer a question, and always attempts to give an answer that User would be satisfied with. It knows a lot, and always tells the truth. The conversation begins.
"""

def format_chat_prompt(message: str, chat_history, instructions: str) -> str:
    instructions = instructions.strip(" ").strip("\n")
    prompt = instructions
    for turn in chat_history:
        user_message, bot_message = turn
        prompt = f"{prompt}\n{USER_NAME}: {user_message}\n{BOT_NAME}: {bot_message}"
    prompt = f"{prompt}\n{USER_NAME}: {message}\n{BOT_NAME}:"
    return prompt

# %%
test_prompt = """Use the below information to answer the following question. If the answer cannot be found with the information, write "I could not find an answer".

\"""Northern War II

***"Do you really wish to know?"*** --- Spoilers from the books and/or adaptations to follow!
The **second Northern War** was an attempt by both Nilfgaard and the Northern Kingdoms to attack each other, starting in 1267 and ending in 1268. In the case of the North, the rulers believed Nilfgaard would keep attacking them and thus they should be the first to strike but make it look like Nilfgaard was the aggressor in order to gain public support. While Nilfgaard, learning of this, quickly prepared its own arms, devised an elaborate plan and struck first, rapidly subduing many surprised northern kingdoms in a blitzkrieg.
\"""
Who fought in the northern war 2?
"""

llm_pipeline(
    format_chat_prompt(test_prompt, [], DEFAULT_INSTRUCTIONS),
    max_new_tokens=1024,
    temperature=0.8,
    top_p=0.9,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    stopping_criteria=StoppingCriteriaList([stop_criteria])
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# ...

# %%
import gradio as gr

USER_NAME = "User"
BOT_NAME = "Falcon"
DEFAULT_INSTRUCTIONS = f"""The following is a conversation between a highly knowledgeable and intelligent AI assistant, called Falcon, and a human user, called User. In the following interactions, User and Falcon will converse in natural language, and Falcon will answer User's questions. Falcon was built to be respectful, polite and inclusive. Falcon will never decline to answer a question, and always attempts to give an answer that User would be satisfied with. It knows a lot, and always tells the truth. The conversation begins.
"""
RETRY_COMMAND = "/retry"
STOP_STR = f"\n{USER_NAME}:"
STOP_SUSPECT_LIST = [":", "\n", "User"]


def chat_accordion():
    with gr.Accordion("Parameters", open=False):
        temperature = gr.Slider(
            minimum=0.1,
            maximum=2.0,
            value=0.8,
            step=0.1,
            interactive=True,
            label="Temperature",
        )
        top_p = gr.Slider(
            minimum=0.1,
            maximum=0.99,
            value=0.9,
            step=0.01,
            interactive=True,
            label="p (nucleus sampling)",
        )
    return temperature, top_p


def format_chat_prompt(message: str, chat_history, instructions: str) -> str:
    instructions = instructions.strip(" ").strip("\n")
    prompt = instructions
    for turn in chat_history:
        user_message, bot_message = turn
        prompt = f"{prompt}\n{USER_NAME}: {user_message}\n{BOT_NAME}: {bot_message}"
    prompt = f"{prompt}\n{USER_NAME}: {message}\n{BOT_NAME}:"
    return prompt


def chat():
    with gr.Column(elem_id="chat_container"):
        with gr.Row():
            chatbot = gr.Chatbot(elem_id="chatbot")
        with gr.Row():
            inputs = gr.Textbox(
                placeholder=f"Hello {BOT_NAME} !!",
                label="Type an input and press Enter",
                max_lines=3,
            )

    with gr.Row(elem_id="button_container"):
        with gr.Column():
            retry_button = gr.Button("♻️ Retry last turn")
        with gr.Column():
            delete_turn_button = gr.Button("🧽 Delete last turn")
        with gr.Column():
            clear_chat_button = gr.Button("✨ Delete all history")

    gr.Examples(
        [
            ["Hey Falcon! Any recommendations for my holidays in Abu Dhabi?"],
            ["What's the Everett interpretation of quantum mechanics?"],
            ["Give me a list of the top 10 dive sites you would recommend around the world."],
            ["Can you tell me more about deep-water soloing?"],
            ["Can you write a short tweet about the Apache 2.0 release of our latest AI model, Falcon LLM?"],
        ],
        inputs=inputs,
        label="Click on any example and press Enter in the input textbox!",
    )

    with gr.Row(elem_id="param_container"):
        with gr.Column():
            temperature, top_p = chat_accordion()
        with gr.Column():
            with gr.Accordion("Instructions", open=False):
                instructions = gr.Textbox(
                    placeholder="LLM instructions",
                    value=DEFAULT_INSTRUCTIONS,
                    lines=10,
                    interactive=True,
                    label="Instructions",
                    max_lines=16,
                    show_label=False,
                )

    def run_chat(message: str, chat_history, instructions: str, temperature: float, top_p: float):
        if not message or (message == RETRY_COMMAND and len(chat_history) == 0):
            yield chat_history
            return

        if message == RETRY_COMMAND and chat_history:
            prev_turn = chat_history.pop(-1)
            user_message, _ = prev_turn
            message = user_message

        prompt = format_chat_prompt(message, chat_history, instructions)
        chat_history = chat_history + [[message, ""]]
        stream = model(
            prompt,
            max_new_tokens=1024,
            stop=[STOP_STR, "<|endoftext|>", USER_NAME],
            temperature=temperature,
            top_p=top_p,
            stream=True
        )
        acc_text = ""
        for idx, response in enumerate(stream):
            text_token = response

            if text_token in STOP_SUSPECT_LIST:
                acc_text += text_token
                continue

            if idx == 0 and text_token.startswith(" "):
                text_token = text_token[1:]

            acc_text += text_token
            last_turn = list(chat_history.pop(-1))
            last_turn[-1] += acc_text
            chat_history = chat_history + [last_turn]
            yield chat_history
            acc_text = ""


    def delete_last_turn(chat_history):
        if chat_history:
            chat_history.pop(-1)
        return {chatbot: gr.update(value=chat_history)}

    def run_retry(message: str, chat_history, instructions: str, temperature: float, top_p: float):
        yield from run_chat(RETRY_COMMAND, chat_history, instructions, temperature, top_p)

    def clear_chat():
        return []

    inputs.submit(
        run_chat,
        [inputs, chatbot, instructions, temperature, top_p],
        outputs=[chatbot],
        show_progress=False,
    )
    inputs.submit(lambda: "", inputs=None, outputs=inputs)
    delete_turn_button.click(delete_last_turn, inputs=[chatbot], outputs=[chatbot])
    retry_button.click(
        run_retry,
        [inputs, chatbot, instructions, temperature, top_p],
        outputs=[chatbot],
        show_progress=False,
    )
    clear_chat_button.click(clear_chat, [], chatbot)


with gr.Blocks(
    # css=None
    # css="""#chat_container {width: 700px; margin-left: auto; margin-right: auto;}
    #        #button_container {width: 700px; margin-left: auto; margin-right: auto;}
    #        #param_container {width: 700px; margin-left: auto; margin-right: auto;}"""
    css="""#chatbot {
font-size: 14px;
min-height: 300px;
}"""
) as demo:
    chat()

demo.queue(concurrency_count=5, max_size=20).launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://d86964a4a7f43a4f22.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d86964a4a7f43a4f22.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/gradio/routes.py", line 439, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/opt/conda/lib/python3.10/site-packages/gradio/blocks.py", line 1384, in process_api
#     result = await self.call_function(
#   File "/opt/conda/lib/python3.10/site-packages/gradio/blocks.py", line 1103, in call_function
#     prediction = await utils.async_iteration(iterator)
# ...
